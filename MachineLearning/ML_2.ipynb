# %% [markdown]
# <a href="https://colab.research.google.com/github/therishabhmittal-05/MachineLearning/blob/master/MachineLearning/ML_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt
dataset = pd.read_csv("Salary_Data.csv")
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 1)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(regressor.coef_)
print(regressor.intercept_)
# Out:
# [9202.23359825]
# 26049.577715443353

# %%
y_predict = regressor.predict(X_test)
print(y_predict)
# Out:
# [ 74821.41578619  91385.43626305  61938.28874864  81262.97930497
#   67459.62890759  88624.76618357 113470.79689886  44454.04491195
#  106109.01002026]

# %%
plt.scatter(X_train, y_train, color = "Orange")
plt.plot(X_train, regressor.predict(X_train), color = "violet")
plt.title("Salary vs Experience (Training Set)")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.show()

# %%
plt.plot(X_train, regressor.predict(X_train), color = "red")
plt.scatter(X_test, y_test, color = "Green")
plt.scatter(X_train, y_train, color = "Orange")
plt.plot(X_test, y_predict, color = "blue")
plt.title("Salary vs Experience (Test Set)")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.show()

# %%
residuals = y_test - y_predict
print(np.sum(np.square(residuals)))

from sklearn.metrics import r2_score
print(r2_score(y_test, y_predict))
# Out:
# 352252943.99629724
# 0.9248580247217075
# [118071.91369799]

# %%
print(regressor.predict([[0]]))
# salary =  regressor.coef_ * YearsOfExperience + regressor.intercept_
# Out:
# [26049.57771544]
