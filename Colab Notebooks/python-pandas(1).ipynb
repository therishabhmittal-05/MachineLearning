# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# a = np.arange(5,25).reshape(5,4)
# b = np.arange(35,55).reshape(5,4)
# print("a is \n",a)
# # print("b is \n",b)
# # print(a+b)
# # print(a-b)
# # print(a*b)
# # print(np.sum(a,axis = 0))
# print(np.sin(a))
# Out:
# array([[ 0.89889936,  0.48656973, -0.28670611,  0.05042263,  0.65275779],
#        [-1.02882646,  0.72382431, -0.63990574,  0.0824244 ,  0.32851056],
#        [-0.32371955,  0.03154777,  0.01080363,  0.16809627,  0.63132816],
#        [ 1.57123358,  0.5297021 , -1.55361163, -1.42124301,  1.13015728],
#        [ 0.28865289,  0.17761649,  1.62910929, -2.38524373, -1.37461845]])

# %%
# pd.Series(Data, index)
series = pd.Series(["Rishabh", "Rahul", "Raman"],[1,2,3])
print(series)
dateRange = pd.date_range("20240505", periods = 2)
pd.DataFrame([["Rishabh", "Rahul"], ["Mahima", "Mandodri"]], dateRange, columns = ["A","B"])
# Out:
# 1    Rishabh
# 2      Rahul
# 3      Raman
# dtype: object
#                   A         B
# 2024-05-05  Rishabh     Rahul
# 2024-05-06   Mahima  Mandodri

# %%
df = pd.DataFrame(randn(5,4),["A","B","C","D","E"], ["!","@","#","$"])
df
# Out:
#           !         @         #         $
# A  1.827137 -0.009018 -0.130258  0.287223
# B  0.666869 -0.901823 -0.191510  1.194297
# C  0.349677  0.341730 -0.075335 -1.964131
# D  1.540829 -0.220007  1.325815 -0.077162
# E -1.429453 -1.667130 -1.332607 -0.999467

# %%
df["!"]
type(df["!"])


dic = {
    "!":"Rishabh",
    "@":"Ramana",
    "#":"Rahul",
    "$":"Mahima"
}
pd.Series(dic)
df[["@","#"]]
df["new1"] = df["!"]+df["#"]
df
df["new2"] = pd.Series(dic)
df.drop('new2', axis = 1)
df.drop('new2', axis = 1, inplace = True)
df.shape
print(df)
df.loc[["A","B","C"],["@","#"]]
# Out:
#           !         @         #         $      new1
# A  1.827137 -0.009018 -0.130258  0.287223  1.696879
# B  0.666869 -0.901823 -0.191510  1.194297  0.475359
# C  0.349677  0.341730 -0.075335 -1.964131  0.274342
# D  1.540829 -0.220007  1.325815 -0.077162  2.866644
# E -1.429453 -1.667130 -1.332607 -0.999467 -2.762061
#           @         #
# A -0.009018 -0.130258
# B -0.901823 -0.191510
# C  0.341730 -0.075335

# %%
df1 = {
    "A":["Apple","Avacado", "AmrishPuri"],
    "B":["Ball", "Bat", "Blazer"],
    "C": ["Cat", "Cow","Car"]
}

# %%
pd.Series(df1)
df2 = pd.DataFrame(df1,["X","Y","Z"])

# pd.Series(data, index)
# pd.DataFrame(data, index, ColumnName)
df2['D']  = df2['A'] + df2["B"]
# print(df2)
print("\n")
df2.drop('D', axis = 1, inplace = True)
type(df2.loc["X"])
from  numpy.random import randn
randn(5,5)
np.random.seed(101)
df = pd.DataFrame(["Q W E".split(), "Q T Y".split(), " U I O".split()], ["A","B","C"], ["W", "X","Y"])
print(df)
print("\n")
# df[df["W"]>0]
# df.loc[["A", "B"], ["W","X"]]
# df>0
# df[df["W"]>0][["Y","Z"]]
# df[(df["W"]>0) & (df['Y']>0)]
# df.set_index("Y")
df.loc[df["W"] == "Q"]
# Out:
#    W  X  Y
# A  Q  W  E
# B  Q  T  Y
# C  U  I  O
#    W  X  Y
# A  Q  W  E
# B  Q  T  Y

# %%
inside = [1,2,3,1,2,3]
outside = "A A A B B B".split()
data = list(zip(outside, inside))
multidf = pd.MultiIndex.from_tuples(data)
nndf = pd.DataFrame(randn(6,2), multidf, ['X', 'Y'])
print(nndf)
print("\n")
nndf.loc["A"]
nndf.index.names = ["Grp", "subGrp"]
nndf
# Out:
#             X         Y
# A 1 -0.131906 -1.335092
#   2 -0.089298  0.698566
#   3 -1.409126  0.870907
# B 1  1.585812  0.929658
#   2 -0.550876  0.942045
#   3 -0.975349 -1.054851
#                    X         Y
# Grp subGrp
# A   1      -0.131906 -1.335092
#     2      -0.089298  0.698566
#     3      -1.409126  0.870907
# B   1       1.585812  0.929658
#     2      -0.550876  0.942045
#     3      -0.975349 -1.054851
