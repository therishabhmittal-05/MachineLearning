# %% [markdown]
# <a href="https://colab.research.google.com/github/therishabhmittal-05/MachineLearning/blob/master/ImageProcessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %%
img01 = cv.imread("baboon.png")
img02 = cv.imread("04.jpg")
img01_RGB= cv.cvtColor(img01, cv.COLOR_BGR2RGB)
img02_RGB= cv.cvtColor(img02, cv.COLOR_BGR2RGB)
plt.imshow(img01_RGB)
plt.show()

# %%
img01_gray = cv.cvtColor(img01, cv.COLOR_BGR2GRAY)
plt.imshow(img01_gray, cmap= "Greys")
plt.show()
plt.imshow(cv.cvtColor(img01, cv.COLOR_RGB2GRAY))
plt.show()

# %%
print(img01.shape)
print(img01_gray.shape)
# Out:
# (512, 512, 3)
# (512, 512)

# %%
red01 = img01[:,:,0]
blue, green, red = img01_RGB[:,:,0], img01_RGB[:,:,1], img01_RGB[:,:,2]
img_bgr = cv.vconcat([blue, green, red])
# plt.imshow(red, cmap= "gray")
# plt.show()

# plt.imshow(blue, cmap= "gray")
# plt.show()

# plt.imshow(green, cmap= "gray")

# plt.show()
plt.imshow(img_bgr, cmap= "gray")

plt.show()

# %%
columns = 256
rows = 256

plt.imshow(img01_RGB[:, columns, :])
plt.show()
